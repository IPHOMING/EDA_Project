# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#dataset from https://data.gov.hk/en-data/dataset/hk-ugc-ugc-average-annual-salaries-graduates

# %%
#Read the CSV file located at the given file path and store the data in the DataFrame 'df'.
path = r"C:\Users\user\Desktop\MiniProject1\Average_Annual_Salaries_FT_Employment(Eng).csv"
df = pd.read_csv(path)
df
# Out:
#     Academic Year         Level of Study Broad Academic Programme Category  \
# 0         2009/10             Sub-degree    Medicine, Dentistry and Health
# 1         2009/10             Sub-degree                          Sciences
# 2         2009/10             Sub-degree        Engineering and Technology
# 3         2009/10             Sub-degree           Business and Management
# 4         2009/10             Sub-degree                   Social Sciences
# ..            ...                    ...                               ...
# 338       2021/22  Research Postgraduate        Engineering and Technology
# 339       2021/22  Research Postgraduate           Business and Management
# 340       2021/22  Research Postgraduate                   Social Sciences
# 341       2021/22  Research Postgraduate               Arts and Humanities
# 342       2021/22  Research Postgraduate                         Education
#
#      Average Annual Salary (HK$'000)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Academic Year                      343 non-null    object
#  1   Level of Study                     343 non-null    object
#  2   Broad Academic Programme Category  343 non-null    object
#  3   Average Annual Salary (HK$'000)    343 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 10.8+ KB

# %%
df.describe()
# Out:
#        Average Annual Salary (HK$'000)
# count                       343.000000
# mean                        277.495627
# std                          96.046190
# min                         120.000000
# 25%                         198.500000
# 50%                         259.000000
# 75%                         344.500000
# max                         577.000000

# %%
#Calculate the count of missing values in each column of the DataFrame 'df'.
df.isnull().sum()
# Out:
# Academic Year                        0
# Level of Study                       0
# Broad Academic Programme Category    0
# Average Annual Salary (HK$'000)      0
# dtype: int64

# %%
#unique value counts for each column in the DataFrame.
df.nunique()
# Out:
# Academic Year                         13
# Level of Study                         4
# Broad Academic Programme Category      7
# Average Annual Salary (HK$'000)      213
# dtype: int64

# %%
# linegraph = sns.lineplot(x="Academic Year" ,y="Average Annual Salary (HK$'000)", hue='Broad Academic Programme Category', data=df,err_style=None)

# %%
#Create a line graph using seaborn library, showing the relationship between "Academic Year" and "Average Annual Salary (HK$'000)" from the DataFrame 'df'. 

linegraph = sns.lineplot(x="Academic Year", y="Average Annual Salary (HK$'000)",linewidth=4, hue='Broad Academic Programme Category', data=df, err_style=None)

linegraph.set_xticklabels(linegraph.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12484\3877186691.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   linegraph.set_xticklabels(linegraph.get_xticklabels(), rotation=40, ha="right")

# %%
#Generate a line graph using seaborn library to visualize the relationship between "Academic Year" and "Average Annual Salary (HK$'000)" from the DataFrame 'df'. 

linegraph = sns.lineplot(x="Academic Year", y="Average Annual Salary (HK$'000)", hue='Level of Study', data=df, err_style=None)

linegraph.set_xticklabels(linegraph.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12484\3150940047.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   linegraph.set_xticklabels(linegraph.get_xticklabels(), rotation=40, ha="right")

# %%
#copy df name as df2
df2=df

# %%
#filter rows where 'Academic Year' == '2021/22'

df2=df2[df2['Academic Year']=='2021/22']

df2
# Out:
#     Academic Year         Level of Study Broad Academic Programme Category  \
# 318       2021/22             Sub-degree                          Sciences
# 319       2021/22             Sub-degree        Engineering and Technology
# 320       2021/22             Sub-degree                   Social Sciences
# 321       2021/22             Sub-degree               Arts and Humanities
# 322       2021/22             Sub-degree                         Education
# 323       2021/22          Undergraduate    Medicine, Dentistry and Health
# 324       2021/22          Undergraduate                          Sciences
# 325       2021/22          Undergraduate        Engineering and Technology
# 326       2021/22          Undergraduate           Business and Management
# 327       2021/22          Undergraduate                   Social Sciences
# 328       2021/22          Undergraduate               Arts and Humanities
# ...

# %%
#This code groups the data by 'Broad Academic Programme Category', calculates the mean of 'Average Annual Salary (HK$'000)', and sorts the results in descending order.

df_mean=df2.groupby('Broad Academic Programme Category')['Average Annual Salary (HK$\'000)'].mean()
df_mean= pd.DataFrame(df_mean)
df_mean.reset_index(inplace=True)
df_sorted = df_mean.sort_values("Average Annual Salary (HK$'000)", ascending=False)
df_sorted
# Out:
#   Broad Academic Programme Category  Average Annual Salary (HK$'000)
# 4    Medicine, Dentistry and Health                           486.00
# 1           Business and Management                           380.50
# 2                         Education                           352.50
# 6                   Social Sciences                           330.50
# 5                          Sciences                           321.25
# 0               Arts and Humanities                           319.75
# 3        Engineering and Technology                           308.00

# %%
#This code creates a bar plot to show the relationship between Broad Academic Programme Category and average salaries.

barplot=sns.barplot(x = 'Broad Academic Programme Category',
            y = "Average Annual Salary (HK$'000)",
            data = df_sorted)

barplot.set_xticklabels(barplot.get_xticklabels(), rotation=40, ha="right")
barplot.legend(fontsize='7')
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#This code generates a bar plot with grouped bars, representing average salaries by Academic Programme categories and levels of study.

barplot=sns.barplot(x = 'Broad Academic Programme Category',
            y = "Average Annual Salary (HK$'000)",
            hue = 'Level of Study',
            data = df)

barplot.set_xticklabels(barplot.get_xticklabels(), rotation=40, ha="right")
barplot.legend(fontsize='7')
plt.tight_layout()
plt.show()

# %%
# df3=df2[df2['Broad Academic Programme Category']=='Engineering and Technology']
# df3
